# %%
#conda install -c conda-forge selenium -y
#!conda install -c conda-forge webdriver-manager -y

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.firefox.options import Options
from selenium.webdriver.firefox.service import Service
from webdriver_manager.firefox import GeckoDriverManager
from selenium.webdriver.common.by import By
from selenium.common import exceptions

import bs4
import json

def bilbasen_interaction(make, model):
    url = f'https://www.bilbasen.dk/brugt/bil/{make}/{model}?IncludeEngrosCVR=true&PriceFrom=0&includeLeasing=false&IncludeCallForPrice=false'
    options = Options()
    options.headless = True
    browser = webdriver.Firefox(service=Service(GeckoDriverManager().install()), options=options)
    browser.get(url)
    
    links = []
    next_page = True;
    
    while (next_page):
        anchor = None;
        next_page = False
        
            #Get all a tags
        browser.refresh()
        elmns = browser.find_elements(By.TAG_NAME,"a")
        for elm in elmns:
            
            try:
                #Find the a tags we need to get links
                if(elm.get_attribute("class") == "listing-heading darkLink"):
                    links.append(elm.get_attribute("href"))
                #Check for next page
                if(elm.get_attribute("class") =="next"):
                    print("next")
                    anchor = elm
                    next_page = True
            except exceptions.StaleElementReferenceException:
                print("stale")
        print(len(links))
            #Go to next page
        if (next_page):
            #anchor.click()
            #anchor.click()
            browser.get(anchor.get_attribute("href"))
                
    browser.close()
    return links

# %%
links = bilbasen_interaction('vw','fox')
#print(source)
# Out:
# [WDM] - Downloading: 19.0kB [00:00, 14.3MB/s]
# [WDM] - Downloading: 100%|██████████| 1.83M/1.83M [00:00<00:00, 9.04MB/s]
# stale
# 14

# %%
p208_links = links

len(p208_links)
# Out:
# 14

# %%
import requests as req
import bs4
import re
import pandas as pd
import json
import time

# %%
def get_details(urls):
    df = pd.DataFrame(columns=['price','model_year','km','reg'])
    i = 0
    for url in urls:
        i+=1
        pct = i/len(urls)*100
        if(i%50 == 0):
            print(f'{pct}%')
        try:
            info_dict ={}
            html = req.get(url)
            soup = bs4.BeautifulSoup(html.text, 'html.parser')
            scripts = soup.select('script')
            script = scripts[-1].text
            json_string = script.replace("var _props = ","").replace(";","")
            json_object = json.loads(json_string)
            info_dict['price']=json_object['listing']['price']['displayValue']
            info_dict['model_year']=json_object['listing']['vehicle']['modelYear']
            info_dict['km']=json_object['tracking']['gtm']['dataLayer']['a']['attr']['vehicle_history_kilometers_driven']
            info_dict['reg']=json_object['tracking']['gtm']['dataLayer']['a']['attr']['vehicle_history_registration_date']
            info_dict['fuel_type'] = json_object['tracking']['gtm']['dataLayer']['a']['attr']['vehicle_model_fuel_type']
            info_dict['fuel_economy'] = json_object['tracking']['gtm']['dataLayer']['a']['attr']['vehicle_model_fuel_economy']
            info_dict['horse_power'] = json_object['tracking']['gtm']['dataLayer']['a']['attr']['vehicle_model_effect']
            info_dict['gear_type'] = json_object['tracking']['gtm']['dataLayer']['a']['attr']['vehicle_model_gear_type']
            info_dict['zip_code'] = json_object['listing']['seller']['address']['zipCode']
            new_row = pd.Series(data= info_dict)
            df = pd.concat([df,new_row.to_frame().T], ignore_index=True) 
            
        except Exception:
            print(url)
    return df

# %%
df = get_details(p208_links)
# Out:
# 6.684491978609626%
# 13.368983957219251%
# https://www.bilbasen.dk/brugt/bil/peugeot/208/12-puretech-75-active-pack-5d/5334873
# 20.053475935828878%
# 26.737967914438503%
# 33.42245989304813%
# 40.106951871657756%
# 46.79144385026738%
# 53.475935828877006%
# https://www.bilbasen.dk/brugt/bil/peugeot/208/12-puretech-100-allure-eat8-5d/5635851
# 60.16042780748663%
# 66.84491978609626%
# 73.52941176470588%
# 80.21390374331551%
# 86.89839572192514%
# 93.58288770053476%

# %%
df
# Out:
#            price model_year      km         reg fuel_type fuel_economy  \
# 0     67.900 kr.       2014  108000  2014-08-12    Benzin         22.2
# 1     59.500 kr.       2015  224000  2015-04-09    Diesel         33.3
# 2    139.900 kr.       2017   58000  2018-01-09    Diesel         28.6
# 3    199.900 kr.       2021   26000  2021-05-21    Benzin         22.8
# 4     75.999 kr.       2013  169000  2012-11-20    Diesel         26.3
# ..           ...        ...     ...         ...       ...          ...
# 741  224.800 kr.       2021    9347  2021-09-20    Benzin         22.8
# 742  224.900 kr.       2021   30000  2021-04-28    Benzin           22
# 743  224.800 kr.       2021    5000  2021-09-13    Benzin         22.8
# 744  224.800 kr.       2021    8529  2021-09-13    Benzin         22.8
# 745   89.900 kr.       2015   85000  2015-07-01    Benzin         22.2
#
#     horse_power gear_type zip_code
# 0            82         M     2610
# 1           100         M     6270
# 2           100         M     3400
# 3           100         M     2610
# 4            68         M     7100
# ..          ...       ...      ...
# 741         100         M     7400
# 742         100         A     7000
# 743         100         M     7400
# 744         100         M     7400
# 745          82         M     3630
#
# [746 rows x 9 columns]

# %%
df.to_csv('208_data.csv', sep=';',index=False)

# %%
up_links[0:1]
# Out:
# ['https://www.bilbasen.dk/brugt/bil/vw/up/10-mpi-60-move-up-bmt-5d/5621117']

# %%
import json

html = req.get('https://www.bilbasen.dk/brugt/bil/vw/polo/10-mpi-75-trendline-5d/5561550')
soup = bs4.BeautifulSoup(html.text, 'html.parser')
scripts = soup.select('script')
script = scripts[-1].text
json_string = script.replace("var _props = ","").replace(";","")
json_object = json.loads(json_string)
#json_object['tracking']['gtm']['dataLayer']['a']['attr']['vehicle_model_gear_type']
json_object
# Out:
# {'listing': {'externalId': 5561550,
#   'syiId': '94c4247b-0af4-cb30-49f5-08da8c1e7c92',
#   'tenant': 'bilinfo',
#   'canonicalUrl': 'https://www.bilbasen.dk/brugt/bil/vw/polo/10-mpi-75-trendline-5d/5561550',
#   'price': {'name': 'Kontantpris', 'displayValue': '149.900 kr.'},
#   'vehicle': {'make': 'VW',
#    'model': 'Polo',
#    'variant': '1,0 MPi 75 Trendline 5d',
#    'modelYear': 2018,
#    'ratings': {'average': 4.1741215141382995,
#     'numberOfReviews': 9175,
#     'subRatings': [{'name': 'Køreegenskaber', 'rating': 4.240180068849854},
#      {'name': 'Driftsomkostninger', 'rating': 4.196912919343326},
#      {'name': 'Sikkerhed', 'rating': 3.966060929983966},
#      {'name': 'Værdi for pengene', 'rating': 4.293332138376053}]},
#    'details': [{'name': 'Modelår', 'displayValue': '2018'},
#     {'name': '1. registrering', 'displayValue': '3/2018'},
#     {'name': 'Kilometertal', 'displayValue': '61.000 km'},
#     {'name': 'Drivmiddel', 'displayValue': 'Benzin'},
#     {'name': 'Brændstofforbrug', 'displayValue': '(NEDC) 20,8 km/l'},
#     {'name': 'CO2 udledning', 'displayValue': '110 g/km'},
#     {'name': 'Euronorm', 'displayValue': '6'},
#     {'name': 'Ejerafgift', 'displayValue': '1.200 kr.'},
#     {'name': 'Ydelse', 'displayValue': '75 hk/95 nm'},
#     {'name': 'Acceleration', 'displayValue': '14,9 sek.'},
#     {'name': 'Tophastighed', 'displayValue': '170 km/t'},
#     {'name': 'Geartype', 'displayValue': 'Manuel'},
#     {'name': 'Antal gear', 'displayValue': '5'},
#     {'name': 'Trækvægt', 'displayValue': '800 kg'},
#     {'name': 'Farve', 'displayValue': 'Sølvmetal'}],
#    'modelInformation': [{'name': 'Nypris', 'displayValue': '157.573 kr.'},
#     {'name': 'Kategori', 'displayValue': 'Personbil'},
#     {'name': 'Type', 'displayValue': 'Mellem'},
#     {'name': 'Vægt', 'displayValue': '1.105 kg'},
#     {'name': 'Bredde', 'displayValue': '175 cm'},
#     {'name': 'Længde', 'displayValue': '406 cm'},
#     {'name': 'Højde', 'displayValue': '146 cm'},
#     {'name': 'Lasteevne', 'displayValue': '425 kg'},
#     {'name': 'Max. trækvægt m/bremse', 'displayValue': '800 kg'},
#     {'name': 'Trækhjul', 'displayValue': 'Forhjulstræk'},
#     {'name': 'Cylindre', 'displayValue': '3'},
#     {'name': 'ABS-bremser', 'displayValue': 'Ja'},
#     {'name': 'ESP', 'displayValue': 'Ja'},
#     {'name': 'Airbags', 'displayValue': '6'},
#     {'name': 'Tankkapacitet', 'displayValue': '40 l'},
#     {'name': 'Døre', 'displayValue': '5'}],
#    'equipment': [{'value': 'ABS-bremser'},
#     {'value': 'Aircondition'},
#     {'value': 'Antispin'},
#     {'value': 'Auto. start/stop'},
#     {'value': 'Bluetooth'},
#     {'value': 'Centrallås'},
#     {'value': 'Centrallås fjernb.'},
#     {'value': 'Dæktryksmåler'},
#     {'value': 'Elruder'},
#     {'value': 'Fartpilot'},
#     {'value': 'Højdejust. førersæde'},
#     {'value': 'Infocenter'},
#     {'value': 'Isofix'},
#     {'value': 'Kørecomputer'},
#     {'value': 'Læderrat'},
#     {'value': 'LED Kørelys'},
#     {'value': 'Musikstreaming via bluetooth'},
#     {'value': 'Sædebetræk, stof'},
#     {'value': 'Service ok'},
#     {'value': 'Servo'},
#     {'value': 'Splitbagsæde'},
#     {'value': 'Startspærre'},
#     {'value': 'Tågelygter'},
#     {'value': 'USB tilslutning'}]},
#   'description': 'SKROT-KAMPAGNE\n\nFÅ MIN. 15.000 DKK FOR DIN BYTTEBIL, VED FINANSIERING AF BIL IGENNEM OS.\n\nMed udbetaling:\nBiler under 5 år gamle: 2,25% rente.\n\nUden Udbetaling\n5,59% rente\n\nHos Bilhuset Storm finder du altid et stort udvalg af brugte familiebiler. Vi har altid minimum 70 biler på lager, både benzin og diesel. Vi kan selvfølgelig også hjælpe med forsikring og finansiering af din nye bil både med og uden udbetaling.\n\nVelkommen hos Bilhuset Storm midt på Sjælland.\n\nNY SYNET 02/2022\nLEVERES NY SERVICERET\n\nairc., c.lås, fjernb. c.lås, fartpilot, kørecomputer, infocenter, startspærre, udv. temp. måler, højdejust. førersæde, el-ruder, automatisk start/stop, cd/radio, dæktryksmåler, håndfrit til mobil, bluetooth, musikstreaming via bluetooth, usb tilslutning, isofix, kopholder, stofindtræk, splitbagsæde, læderrat, tågelygter, led kørelys, airbag, abs, antispin, esp, servo, ikke ryger, nysynet, service ok, tidligere undervognsbehandlet\n\nATTRAKTIV FINANSERING KAN SKAFFES MED OG UDEN UDBETALING.\n\nDenne bil er en Euro VI norm hvilket vil sige at den opfylder kravene for at køre i de større byer.\n\nAlle vores biler leveres serviceret og kosmetisk klargjort. Det er din tryghed for en god bilhandel. Ja tak til byttebiler. Finansiering både med og uden udbetaling tilbydes til attraktive renter.\n\nÅBNINGSTIDER hos Bilhuset Storm:\nMandag - fredag: 10:00 - 17:00\nLørdag lukket\nSøndag: 11:00 - 15:00',
#   'media': {'images': [{'url': 'https://billeder.bilbasen.dk/bilinfo/87814a8a-1928-485d-8df2-3538b48b7840.jpeg?class=S960X960'},
#     {'url': 'https://billeder.bilbasen.dk/bilinfo/c3e25c36-b388-4058-a882-b08f9a784f73.jpeg?class=S960X960'},
#     {'url': 'https://billeder.bilbasen.dk/bilinfo/f6fd6456-e6ba-4971-a773-06e2a5ff5e94.jpeg?class=S960X960'},
#     {'url': 'https://billeder.bilbasen.dk/bilinfo/b66740b9-6d74-4f6c-b045-8c279631c2a9.jpeg?class=S960X960'},
#     {'url': 'https://billeder.bilbasen.dk/bilinfo/8c45d842-6c93-4ec7-8eae-82daab730219.jpeg?class=S960X960'},
#     {'url': 'https://billeder.bilbasen.dk/bilinfo/7192d522-eb64-4bee-88b9-dc406f11ef98.jpeg?class=S960X960'},
#     {'url': 'https://billeder.bilbasen.dk/bilinfo/b774f650-fa97-4d42-8383-f5ce55340256.jpeg?class=S960X960'},
#     {'url': 'https://billeder.bilbasen.dk/bilinfo/8d28ca0c-5529-4c74-b4d7-5a4f392a52e2.jpeg?class=S960X960'},
#     {'url': 'https://billeder.bilbasen.dk/bilinfo/7b750798-47d6-47fc-9362-433313fb7b63.jpeg?class=S960X960'},
#     {'url': 'https://billeder.bilbasen.dk/bilinfo/30e443e8-f0de-4cd9-b82a-b45ceaf804ce.jpeg?class=S960X960'},
#     {'url': 'https://billeder.bilbasen.dk/bilinfo/898c2855-2a20-4921-9817-f5a5f0272cab.jpeg?class=S960X960'},
#     {'url': 'https://billeder.bilbasen.dk/bilinfo/87820193-20c5-490f-9868-4964a364acd1.jpeg?class=S960X960'},
#     {'url': 'https://billeder.bilbasen.dk/bilinfo/20645cdc-c8fc-46a2-b187-5be8ef4f5e9f.jpeg?class=S960X960'},
#     {'url': 'https://billeder.bilbasen.dk/bilinfo/7ec5ac09-16a0-4461-8890-193098c1a990.jpeg?class=S960X960'},
#     {'url': 'https://billeder.bilbasen.dk/bilinfo/443385db-ea95-47e1-9bff-66c70e59f792.jpeg?class=S960X960'},
#     {'url': 'https://billeder.bilbasen.dk/bilinfo/9148898d-dd43-4554-8cf5-27d15b7a14ad.jpeg?class=S960X960'},
#     {'url': 'https://billeder.bilbasen.dk/bilinfo/16965eed-a322-4384-bdd1-cb1248450e0a.jpeg?class=S960X960'},
#     {'url': 'https://billeder.bilbasen.dk/bilinfo/efdee47b-f316-40cc-8437-ab5dfb06e36f.jpeg?class=S960X960'}],
#    'fullscreenImages': [{'url': 'https://billeder.bilbasen.dk/bilinfo/87814a8a-1928-485d-8df2-3538b48b7840.jpeg?class=S1600X1600'},
#     {'url': 'https://billeder.bilbasen.dk/bilinfo/c3e25c36-b388-4058-a882-b08f9a784f73.jpeg?class=S1600X1600'},
#     {'url': 'https://billeder.bilbasen.dk/bilinfo/f6fd6456-e6ba-4971-a773-06e2a5ff5e94.jpeg?class=S1600X1600'},
#     {'url': 'https://billeder.bilbasen.dk/bilinfo/b66740b9-6d74-4f6c-b045-8c279631c2a9.jpeg?class=S1600X1600'},
#     {'url': 'https://billeder.bilbasen.dk/bilinfo/8c45d842-6c93-4ec7-8eae-82daab730219.jpeg?class=S1600X1600'},
#     {'url': 'https://billeder.bilbasen.dk/bilinfo/7192d522-eb64-4bee-88b9-dc406f11ef98.jpeg?class=S1600X1600'},
#     {'url': 'https://billeder.bilbasen.dk/bilinfo/b774f650-fa97-4d42-8383-f5ce55340256.jpeg?class=S1600X1600'},
#     {'url': 'https://billeder.bilbasen.dk/bilinfo/8d28ca0c-5529-4c74-b4d7-5a4f392a52e2.jpeg?class=S1600X1600'},
#     {'url': 'https://billeder.bilbasen.dk/bilinfo/7b750798-47d6-47fc-9362-433313fb7b63.jpeg?class=S1600X1600'},
#     {'url': 'https://billeder.bilbasen.dk/bilinfo/30e443e8-f0de-4cd9-b82a-b45ceaf804ce.jpeg?class=S1600X1600'},
#     {'url': 'https://billeder.bilbasen.dk/bilinfo/898c2855-2a20-4921-9817-f5a5f0272cab.jpeg?class=S1600X1600'},
#     {'url': 'https://billeder.bilbasen.dk/bilinfo/87820193-20c5-490f-9868-4964a364acd1.jpeg?class=S1600X1600'},
#     {'url': 'https://billeder.bilbasen.dk/bilinfo/20645cdc-c8fc-46a2-b187-5be8ef4f5e9f.jpeg?class=S1600X1600'},
#     {'url': 'https://billeder.bilbasen.dk/bilinfo/7ec5ac09-16a0-4461-8890-193098c1a990.jpeg?class=S1600X1600'},
#     {'url': 'https://billeder.bilbasen.dk/bilinfo/443385db-ea95-47e1-9bff-66c70e59f792.jpeg?class=S1600X1600'},
#     {'url': 'https://billeder.bilbasen.dk/bilinfo/9148898d-dd43-4554-8cf5-27d15b7a14ad.jpeg?class=S1600X1600'},
#     {'url': 'https://billeder.bilbasen.dk/bilinfo/16965eed-a322-4384-bdd1-cb1248450e0a.jpeg?class=S1600X1600'},
#     {'url': 'https://billeder.bilbasen.dk/bilinfo/efdee47b-f316-40cc-8437-ab5dfb06e36f.jpeg?class=S1600X1600'}]},
#   'seller': {'id': 12875,
#    'name': 'Bilhuset Storm',
#    'type': 'Dealer',
#    'tenant': 'Bilinfo',
#    'address': {'line1': 'Hovedvejen 180, Osted',
#     'line2': '4320 Lejre',
#     'zipCode': 4320,
#     'city': 'Lejre',
#     'country': 'Danmark'},
#    'phoneNumbers': [{'info': '', 'number': '46400019'},
#     {'info': '', 'number': '21201900'}],
#    'sellerOtherItems': {'url': '/find-en-forhandler/bilforhandler--id12875'},
#    'features': {'isNemIdValidated': False,
#     'website': 'https://www.bilhusetstorm.dk/?utm_source=bilbasen&utm_medium=referral',
#     'dealerProfile': {'topLogo': {'url': 'https://billeder.bilbasen.dk/bilinfo/16547215-8e53-44a7-8ddc-b35f87d3b95d.jpg?class=S400X400'},
#      'image': {'url': 'https://billeder.bilbasen.dk/bilinfo/86643f1b-81be-45bc-8eab-fefb93390e35.jpg?class=S400X400'},
#      'logo': {'url': 'https://billeder.bilbasen.dk/bilinfo/4a9768d7-aef1-4551-80a7-b2e3f505c984.jpg?class=S400X400'},
#      'description': 'Hos Bilhuset Storm forsøger vi altid at møde vores kunder i øjenhøjde. Vi er et team som har været i bilbranchen i mange år. Vi forsøger altid at have et stort udvalg af biler - Til de rigtige priser. \nFinansiering med og uden udbetaling. Ring og hør nærmere.\nKom forbi vores forretning og se om vi ikke også har den rigtige bil til dig/jer. \nVi glæder os til at byde jer velkommen :-)\n\n',
#      'uniqueSellingPoints': ['Stort udvalg af kvalitetsbiler.',
#       'Attraktiv finansiering.',
#       'Vi tager alle biler i bytte.',
#       'Mulighed for ekstra garanti.']},
#     'eidValidation': 'None'},
#    'hasEmail': True,
#    'phoneNumberType': 'DynamicVirtual'}},
#  'writeToSellerOptions': {'contact': {'rel': 'Navigate',
#    'href': '/host/leadqualification/5561550',
#    'caption': 'Skriv til sælger'}},
#  'tracking': {'gtm': {'dataLayer': {'p': {'t': 'VIP',
#      'pl': 'bilbasen-desktop'},
#     'a': {'id': 5561550,
#      't': 'OFFERED',
#      'cdt': 1662040817,
#      'age': 87,
#      'lpdt': 1669542005,
#      'dl': 1399,
#      'i': ['https://billeder.bilinfo.net/bilinfo/87814a8a-1928-485d-8df2-3538b48b7840.jpeg',
#       'https://billeder.bilinfo.net/bilinfo/c3e25c36-b388-4058-a882-b08f9a784f73.jpeg',
#       'https://billeder.bilinfo.net/bilinfo/f6fd6456-e6ba-4971-a773-06e2a5ff5e94.jpeg',
#       'https://billeder.bilinfo.net/bilinfo/b66740b9-6d74-4f6c-b045-8c279631c2a9.jpeg',
#       'https://billeder.bilinfo.net/bilinfo/8c45d842-6c93-4ec7-8eae-82daab730219.jpeg',
#       'https://billeder.bilinfo.net/bilinfo/7192d522-eb64-4bee-88b9-dc406f11ef98.jpeg',
#       'https://billeder.bilinfo.net/bilinfo/b774f650-fa97-4d42-8383-f5ce55340256.jpeg',
#       'https://billeder.bilinfo.net/bilinfo/8d28ca0c-5529-4c74-b4d7-5a4f392a52e2.jpeg',
#       'https://billeder.bilinfo.net/bilinfo/7b750798-47d6-47fc-9362-433313fb7b63.jpeg',
#       'https://billeder.bilinfo.net/bilinfo/30e443e8-f0de-4cd9-b82a-b45ceaf804ce.jpeg',
#       'https://billeder.bilinfo.net/bilinfo/898c2855-2a20-4921-9817-f5a5f0272cab.jpeg',
#       'https://billeder.bilinfo.net/bilinfo/87820193-20c5-490f-9868-4964a364acd1.jpeg',
#       'https://billeder.bilinfo.net/bilinfo/20645cdc-c8fc-46a2-b187-5be8ef4f5e9f.jpeg',
#       'https://billeder.bilinfo.net/bilinfo/7ec5ac09-16a0-4461-8890-193098c1a990.jpeg',
#       'https://billeder.bilinfo.net/bilinfo/443385db-ea95-47e1-9bff-66c70e59f792.jpeg',
#       'https://billeder.bilinfo.net/bilinfo/9148898d-dd43-4554-8cf5-27d15b7a14ad.jpeg',
#       'https://billeder.bilinfo.net/bilinfo/16965eed-a322-4384-bdd1-cb1248450e0a.jpeg',
#       'https://billeder.bilinfo.net/bilinfo/efdee47b-f316-40cc-8437-ab5dfb06e36f.jpeg'],
#      'ic': 18,
#      'prc': {'amt': 14990000, 'cur': 'DKK'},
#      'ftr': ['ad-type-medium', 'ad-feature-bump-up-forteendays'],
#      'u': {'li': False,
#       'huid': 'DAD02CCCD52245A45C5036338A1FB49B',
#       'hue': 'nyKyhTTBrEYK0BL1FKYfOvtpsbdRJzK1p7OJapmYfhSXNnMKLlUKPftLaRFw8T3gMUiCsfpZqxppf8t6Q',
#       'ppid': 'nyKyhTTBrEYK0BL1FKYfOvtpsbdRJzK1p7OJapmYfhSXNnMKLlUKPftLaRFw8T3gMUiCsfpZqxppf8t6Q',
#       'at': 'Dealer',
#       'tg': {'stg': ''},
#       'roles': [],
#       'nemid': False,
#       'eid': False},
#      'attr': {'vehicle_listing_source': 'Bilinfo',
#       'attr_dealerid': '12875',
#       'vehicle_owner_seller_type': 'TRADE',
#       'vehicle_history_registration_date': '2018-03-07',
#       'vehicle_history_latest_mot': '2022-2',
#       'vehicle_history_service': 'full',
#       'vehicle_history_kilometers_driven': '61000',
#       'vehicle_price_delivery_price': '0',
#       'vehicle_color_name': 'sølvmetal',
#       'vehicle_equipment_absbrakes': 'True',
#       'vehicle_equipment_aircondition': 'True',
#       'vehicle_equipment_antispin': 'True',
#       'vehicle_equipment_autostartstop': 'True',
#       'vehicle_equipment_bluetooth': 'True',
#       'vehicle_equipment_centrallocking': 'True',
#       'vehicle_equipment_remotecentrallocking': 'True',
#       'vehicle_equipment_tirepressuresystem': 'True',
#       'vehicle_equipment_poweredsidewindows': 'True',
#       'vehicle_equipment_cruisecontrol': 'True',
#       'vehicle_equipment_heightadjustabledriversseat': 'True',
#       'vehicle_equipment_infocenter': 'True',
#       'vehicle_equipment_isofix': 'True',
#       'vehicle_equipment_onboardcomputer': 'True',
#       'vehicle_equipment_leddrivinglights': 'True',
#       'vehicle_equipment_leathersteeringwheel': 'True',
#       'vehicle_equipment_bluetoothaudiostreaming': 'True',
#       'vehicle_equipment_serviceok': 'True',
#       'vehicle_equipment_powerassistedsteering': 'True',
#       'vehicle_equipment_splitfoldingrearseats': 'True',
#       'vehicle_equipment_immobilizer': 'True',
#       'vehicle_equipment_fabricseats': 'True',
#       'vehicle_equipment_foglamps': 'True',
#       'vehicle_equipment_usbconnection': 'True',
#       'vehicle_model_weight_tax_calculated': '1200',
#       'vehicle_model_weight_tax_period_calculated': '12',
#       'vehicle_model_catalogue_id': '8653428e-051e-c024-f736-08d5070a3ed5',
#       'vehicle_model_year': '2018',
#       'vehicle_model_production_start_year': '2017',
#       'vehicle_model_production_end_year': '2021',
#       'vehicle_model_price_from_new': '157573',
#       'vehicle_model_newest_price_from_new': '0',
#       'vehicle_model_gear_type': 'M',
#       'vehicle_model_gear_count': '5',
#       'vehicle_model_gear': '5',
#       'vehicle_model_motor': '1,0',
#       'vehicle_model_motor_num_cylinders': '3',
#       'vehicle_model_fuel_type': 'Benzin',
#       'vehicle_model_fuel_economy': '20.8',
#       'vehicle_model_fuel_max': '40',
#       'vehicle_model_dimension_length': '406',
#       'vehicle_model_dimension_width': '175',
#       'vehicle_model_dimension_height': '146',
#       'vehicle_model_load_capacity': '425',
#       'vehicle_model_weight': '1105',
#       'vehicle_model_trailer_weight': '800',
#       'vehicle_model_acc_0_to_100_kmh': '14.9',
#       'vehicle_model_top_speed': '170',
#       'vehicle_model_effect_nm': '95',
#       'vehicle_model_effect': '75',
#       'vehicle_model_airbag_count': '6',
#       'vehicle_model_drive_wheels': 'F',
#       'vehicle_model_num_doors': '5',
#       'vehicle_model_type': 'Halvkombi'},
#      'syiId': '94c4247b-0af4-cb30-49f5-08da8c1e7c92'},
#     'c': {'l1': {'id': 11, 'n': 'P'},
#      'l2': {'id': 689, 'n': 'VW'},
#      'l3': {'id': 305, 'n': 'Polo'},
#      'l4': {'id': 32488, 'n': 'MPi 75 Trendline'},
#      'c': {'id': 32488, 'n': 'MPi 75 Trendline'}},
#     'l': {'c': {'id': 4320, 'n': 'Lejre'},
#      'l1': {'id': 1, 'n': 'Denmark'},
#      'l2': {'id': 1085, 'n': 'Region Sjælland'},
#      'l3': {'id': 265, 'n': 'Roskilde Kommune'},
#      'l4': {'id': 4320, 'n': 'Lejre'},
#      'ltlng': '55.6011.96',
#      'pcid': '4320'}}},
#   'pulse': {'pulse': {'@type': 'View',
#     'object': {'internalId': 'sdrn:bilinfo:classified:94c4247b-0af4-cb30-49f5-08da8c1e7c92',
#      'contentId': '5561550',
#      'categories': [{'@type': 'MarketplaceCategory',
#        'level': 0,
#        'localId': '11',
#        'localName': 'P'},
#       {'@type': 'MarketplaceCategory',
#        'level': 1,
#        'localId': '689',
#        'localName': 'VW'},
#       {'@type': 'MarketplaceCategory',
#        'level': 2,
#        'localId': '305',
#        'localName': 'Polo'},
#       {'@type': 'MarketplaceCategory',
#        'level': 3,
#        'localId': '32488',
#        'localName': 'MPi 75 Trendline'}],
#      'price': 149900.0,
#      'currency': 'DKK',
#      'publicationDate': '2022-09-01T14:00:16.8234678Z',
#      'lastUpdateDate': '2022-11-27T10:40:04.5115898Z',
#      '@id': 'sdrn:bilbasen:classified:5561550',
#      '@type': 'ClassifiedAd',
#      'name': 'VIP',
#      'category': 'P > VW > Polo > MPi 75 Trendline'},
#     'deployStage': 'pro'}}},
#  'relatedListings': {'title': 'Lignende biler',
#   'items': [{'externalId': 5643981,
#     'priceDisplayValue': '174.900 kr.',
#     'title': 'VW Polo',
#     'subTitle': '1,0 TSi 95 Comfortline 5d',
#     'infoText': 'Modelår 2019, 60.000 km, Benzin, 24 km/l',
#     'image': {'url': 'https://billeder.bilbasen.dk/bilinfo/a34a3242-314c-4419-b8ae-f7449d4e1e29.jpeg?class=S960X960'},
#     'link': {'rel': 'Navigate',
#      'href': 'https://www.bilbasen.dk/brugt/bil/vw/polo/10-tsi-95-comfortline-5d/5643981',
#      'gaTrackingText': 'OpenClickXtra'},
#     'tracking': {'rel': 'TrackClick',
#      'href': '/LogMoonrakerClick/5643981/103/1',
#      'method': 'POST'}},
#    {'externalId': 5595093,
#     'priceDisplayValue': '174.900 kr.',
#     'title': 'VW Polo',
#     'subTitle': '1,0 TSi 95 Comfortline+ 5d',
#     'infoText': 'Modelår 2020, 67.000 km, Benzin, 24 km/l',
#     'image': {'url': 'https://billeder.bilbasen.dk/bilinfo/3f50a21c-50c6-41f3-9e67-51f99dfa590a.jpeg?class=S960X960'},
#     'link': {'rel': 'Navigate',
#      'href': 'https://www.bilbasen.dk/brugt/bil/vw/polo/10-tsi-95-comfortline-5d/5595093',
#      'gaTrackingText': 'OpenClickXtra'},
#     'tracking': {'rel': 'TrackClick',
#      'href': '/LogMoonrakerClick/5595093/103/1',
#      'method': 'POST'}},
#    {'externalId': 5584210,
#     'priceDisplayValue': '169.900 kr.',
#     'title': 'VW Polo',
#     'subTitle': '1,0 TSi 95 Comfortline 5d',
#     'infoText': 'Modelår 2019, 47.000 km, Benzin, 24 km/l',
#     'image': {'url': 'https://billeder.bilbasen.dk/bilinfo/985ba71a-7dfe-41ca-894e-e9819e23483b.jpeg?class=S960X960'},
#     'link': {'rel': 'Navigate',
#      'href': 'https://www.bilbasen.dk/brugt/bil/vw/polo/10-tsi-95-comfortline-5d/5584210',
#      'gaTrackingText': 'OpenClickXtra'},
#     'tracking': {'rel': 'TrackClick',
#      'href': '/LogMoonrakerClick/5584210/103/1',
#      'method': 'POST'}},
#    {'externalId': 5642868,
#     'priceDisplayValue': '174.900 kr.',
#     'title': 'VW Polo',
#     'subTitle': '1,0 TSi 95 Comfortline Connect 5d',
#     'infoText': 'Modelår 2019, 63.000 km, Benzin, 24 km/l',
#     'image': {'url': 'https://billeder.bilbasen.dk/bilinfo/5678d5b8-280e-443c-85ec-5c850fd45b3d.jpeg?class=S960X960'},
#     'link': {'rel': 'Navigate',
#      'href': 'https://www.bilbasen.dk/brugt/bil/vw/polo/10-tsi-95-comfortline-connect-5d/5642868',
#      'gaTrackingText': 'OpenClickXtra'},
#     'tracking': {'rel': 'TrackClick',
#      'href': '/LogMoonrakerClick/5642868/103/1',
#      'method': 'POST'}},
#    {'externalId': 5643876,
#     'priceDisplayValue': '134.900 kr.',
#     'title': 'VW Polo',
#     'subTitle': '1,0 TSi 95 BlueMotion 5d',
#     'infoText': 'Modelår 2017, 55.000 km, Benzin, 24 km/l',
#     'image': {'url': 'https://billeder.bilbasen.dk/bilinfo/8ab84a24-db4a-4269-948b-033deec59b3b.jpeg?class=S960X960'},
#     'link': {'rel': 'Navigate',
#      'href': 'https://www.bilbasen.dk/brugt/bil/vw/polo/10-tsi-95-bluemotion-5d/5643876',
#      'gaTrackingText': 'OpenClickXtra'},
#     'tracking': {'rel': 'TrackClick',
#      'href': '/LogMoonrakerClick/5643876/103/1',
#      'method': 'POST'}},
#    {'externalId': 5603316,
#     'priceDisplayValue': '164.900 kr.',
#     'title': 'VW Polo',
#     'subTitle': '1,0 TSi 95 Comfortline 5d',
#     'infoText': 'Modelår 2019, 52.000 km, Benzin, 24 km/l',
#     'image': {'url': 'https://billeder.bilbasen.dk/bilinfo/09d8f822-ab09-409d-82e8-8c3ea40eb8d8.jpeg?class=S960X960'},
#     'link': {'rel': 'Navigate',
#      'href': 'https://www.bilbasen.dk/brugt/bil/vw/polo/10-tsi-95-comfortline-5d/5603316',
#      'gaTrackingText': 'OpenClickXtra'},
#     'tracking': {'rel': 'TrackClick',
#      'href': '/LogMoonrakerClick/5603316/103/1',
#      'method': 'POST'}},
#    {'externalId': 5622644,
#     'priceDisplayValue': '174.900 kr.',
#     'title': 'VW Polo',
#     'subTitle': '1,0 TSi 95 Comfortline 5d',
#     'infoText': 'Modelår 2019, 50.000 km, Benzin, 24 km/l',
#     'image': {'url': 'https://billeder.bilbasen.dk/bilinfo/1972b8c6-4d3c-408f-8e96-5444617c276e.jpeg?class=S960X960'},
#     'link': {'rel': 'Navigate',
#      'href': 'https://www.bilbasen.dk/brugt/bil/vw/polo/10-tsi-95-comfortline-5d/5622644',
#      'gaTrackingText': 'OpenClickXtra'},
#     'tracking': {'rel': 'TrackClick',
#      'href': '/LogMoonrakerClick/5622644/103/1',
#      'method': 'POST'}},
#    {'externalId': 5640612,
#     'priceDisplayValue': '139.900 kr.',
#     'title': 'VW Polo',
#     'subTitle': '1,2 TSi 90 Comfortline BMT 5d',
#     'infoText': 'Modelår 2017, 69.000 km, Benzin, 21 km/l',
#     'image': {'url': 'https://billeder.bilbasen.dk/bilinfo/3322a4df-5efa-4533-bdc6-da6042b255f9.jpeg?class=S960X960'},
#     'link': {'rel': 'Navigate',
#      'href': 'https://www.bilbasen.dk/brugt/bil/vw/polo/12-tsi-90-comfortline-bmt-5d/5640612',
#      'gaTrackingText': 'OpenClickXtra'},
#     'tracking': {'rel': 'TrackClick',
#      'href': '/LogMoonrakerClick/5640612/103/1',
#      'method': 'POST'}},
#    {'externalId': 5639913,
#     'priceDisplayValue': '149.900 kr.',
#     'title': 'VW Polo',
#     'subTitle': '1,0 MPi 75 Trendline 5d',
#     'infoText': 'Modelår 2018, 67.000 km, Benzin, 21 km/l',
#     'image': {'url': 'https://billeder.bilbasen.dk/bilinfo/de848fbd-32e5-480f-b36d-a42d4f9a9484.jpeg?class=S960X960'},
#     'link': {'rel': 'Navigate',
#      'href': 'https://www.bilbasen.dk/brugt/bil/vw/polo/10-mpi-75-trendline-5d/5639913',
#      'gaTrackingText': 'OpenClickXtra'},
#     'tracking': {'rel': 'TrackClick',
#      'href': '/LogMoonrakerClick/5639913/103/1',
#      'method': 'POST'}},
#    {'externalId': 5557359,
#     'priceDisplayValue': '169.900 kr.',
#     'title': 'VW Polo',
#     'subTitle': '1,6 TDi 95 Comfortline 5d',
#     'infoText': 'Modelår 2019, 108.000 km, Diesel, 30 km/l',
#     'image': {'url': 'https://billeder.bilbasen.dk/bilinfo/45b765bf-d100-4168-b586-3fed14efcddc.jpeg?class=S960X960'},
#     'link': {'rel': 'Navigate',
#      'href': 'https://www.bilbasen.dk/brugt/bil/vw/polo/16-tdi-95-comfortline-5d/5557359',
#      'gaTrackingText': 'OpenClickXtra'},
#     'tracking': {'rel': 'TrackClick',
#      'href': '/LogMoonrakerClick/5557359/103/1',
#      'method': 'POST'}},
#    {'externalId': 5360166,
#     'priceDisplayValue': '129.900 kr.',
#     'title': 'VW Polo',
#     'subTitle': '1,2 TSi 90 Highline DSG 5d',
#     'infoText': 'Modelår 2013, 130.000 km, Benzin, 19 km/l',
#     'image': {'url': 'https://billeder.bilbasen.dk/bilinfo/231db499-3f46-4d8e-9ed9-34fa4bc04c9d.jpg?class=S960X960'},
#     'link': {'rel': 'Navigate',
#      'href': 'https://www.bilbasen.dk/brugt/bil/vw/polo/12-tsi-90-highline-dsg-5d/5360166',
#      'gaTrackingText': 'OpenClickXtra'},
#     'tracking': {'rel': 'TrackClick',
#      'href': '/LogMoonrakerClick/5360166/103/1',
#      'method': 'POST'}},
#    {'externalId': 5591923,
#     'priceDisplayValue': '173.900 kr.',
#     'title': 'VW Polo',
#     'subTitle': '1,0 TSi 95 Comfortline DSG 5d',
#     'infoText': 'Modelår 2018, 92.000 km, Benzin, 22 km/l',
#     'image': {'url': 'https://billeder.bilbasen.dk/bilinfo/5fca19b4-da90-4207-89d4-98442a4ea282.jpeg?class=S960X960'},
#     'link': {'rel': 'Navigate',
#      'href': 'https://www.bilbasen.dk/brugt/bil/vw/polo/10-tsi-95-comfortline-dsg-5d/5591923',
#      'gaTrackingText': 'OpenClickXtra'},
#     'tracking': {'rel': 'TrackClick',
#      'href': '/LogMoonrakerClick/5591923/103/1',
#      'method': 'POST'}},
#    {'externalId': 5612604,
#     'priceDisplayValue': '152.500 kr.',
#     'title': 'VW Polo',
#     'subTitle': '1,4 TDi 90 Comfortline DSG BMT 5d',
#     'infoText': 'Modelår 2016, 96.000 km, Diesel, 29 km/l',
#     'image': {'url': 'https://billeder.bilbasen.dk/bilinfo/573eebd4-b0a8-4feb-bc27-e807794664a9.jpeg?class=S960X960'},
#     'link': {'rel': 'Navigate',
#      'href': 'https://www.bilbasen.dk/brugt/bil/vw/polo/14-tdi-90-comfortline-dsg-bmt-5d/5612604',
#      'gaTrackingText': 'OpenClickXtra'},
#     'tracking': {'rel': 'TrackClick',
#      'href': '/LogMoonrakerClick/5612604/103/1',
#      'method': 'POST'}},
#    {'externalId': 5625502,
#     'priceDisplayValue': '164.990 kr.',
#     'title': 'VW Polo',
#     'subTitle': '1,0 TSi 95 Comfortline 5d',
#     'infoText': 'Modelår 2018, 34.000 km, Benzin, 23 km/l',
#     'image': {'url': 'https://billeder.bilbasen.dk/bilinfo/db1d8aa3-8f2f-4503-927c-49e43e2bf897.jpeg?class=S960X960'},
#     'link': {'rel': 'Navigate',
#      'href': 'https://www.bilbasen.dk/brugt/bil/vw/polo/10-tsi-95-comfortline-5d/5625502',
#      'gaTrackingText': 'OpenClickXtra'},
#     'tracking': {'rel': 'TrackClick',
#      'href': '/LogMoonrakerClick/5625502/103/1',
#      'method': 'POST'}},
#    {'externalId': 5620035,
#     'priceDisplayValue': '129.900 kr.',
#     'title': 'VW Polo',
#     'subTitle': '1,2 TSi 90 Comfortline BMT 5d',
#     'infoText': 'Modelår 2016, 91.000 km, Benzin, 21 km/l',
#     'image': {'url': 'https://billeder.bilbasen.dk/bilinfo/0a019e23-e152-495e-9813-87f28920af10.jpeg?class=S960X960'},
#     'link': {'rel': 'Navigate',
#      'href': 'https://www.bilbasen.dk/brugt/bil/vw/polo/12-tsi-90-comfortline-bmt-5d/5620035',
#      'gaTrackingText': 'OpenClickXtra'},
#     'tracking': {'rel': 'TrackClick',
#      'href': '/LogMoonrakerClick/5620035/103/1',
#      'method': 'POST'}},
#    {'externalId': 5636806,
#     'priceDisplayValue': '214.900 kr.',
#     'title': 'VW Polo',
#     'subTitle': '1,0 TSi 115 Highline DSG 5d',
#     'infoText': 'Modelår 2019, 53.000 km, Benzin, 23 km/l',
#     'image': {'url': 'https://billeder.bilbasen.dk/bilinfo/ce27f8bd-5d99-4607-bb12-d77e7638dcbf.jpeg?class=S960X960'},
#     'link': {'rel': 'Navigate',
#      'href': 'https://www.bilbasen.dk/brugt/bil/vw/polo/10-tsi-115-highline-dsg-5d/5636806',
#      'gaTrackingText': 'OpenClickXtra'},
#     'tracking': {'rel': 'TrackClick',
#      'href': '/LogMoonrakerClick/5636806/103/1',
#      'method': 'POST'}},
#    {'externalId': 5629477,
#     'priceDisplayValue': '265.900 kr.',
#     'title': 'VW Polo',
#     'subTitle': '1,5 TSi 150 R-line DSG 5d',
#     'infoText': 'Modelår 2020, 51.000 km, Benzin, 22 km/l',
#     'image': {'url': 'https://billeder.bilbasen.dk/bilinfo/dcf9f57c-d324-4e3d-9fc0-5bc05bee639e.jpeg?class=S960X960'},
#     'link': {'rel': 'Navigate',
#      'href': 'https://www.bilbasen.dk/brugt/bil/vw/polo/15-tsi-150-r-line-dsg-5d/5629477',
#      'gaTrackingText': 'OpenClickXtra'},
#     'tracking': {'rel': 'TrackClick',
#      'href': '/LogMoonrakerClick/5629477/103/1',
#      'method': 'POST'}},
#    {'externalId': 5626010,
#     'priceDisplayValue': '184.900 kr.',
#     'title': 'VW Polo',
#     'subTitle': '1,0 TSi 95 Comfortline+ 5d',
#     'infoText': 'Modelår 2020, 65.000 km, Benzin, 24 km/l',
#     'image': {'url': 'https://billeder.bilbasen.dk/bilinfo/8827c4cd-f2b6-4e3b-b94b-e54c7d22f6ad.jpeg?class=S960X960'},
#     'link': {'rel': 'Navigate',
#      'href': 'https://www.bilbasen.dk/brugt/bil/vw/polo/10-tsi-95-comfortline-5d/5626010',
#      'gaTrackingText': 'OpenClickXtra'},
#     'tracking': {'rel': 'TrackClick',
#      'href': '/LogMoonrakerClick/5626010/103/1',
#      'method': 'POST'}},
#    {'externalId': 5618299,
#     'priceDisplayValue': '199.900 kr.',
#     'title': 'VW Polo',
#     'subTitle': '1,0 TSi 115 Highline DSG 5d',
#     'infoText': 'Modelår 2019, 52.000 km, Benzin, 23 km/l',
#     'image': {'url': 'https://billeder.bilbasen.dk/bilinfo/9c1ad9d9-52bd-46a5-a91a-c1d1ec13dec3.jpeg?class=S960X960'},
#     'link': {'rel': 'Navigate',
#      'href': 'https://www.bilbasen.dk/brugt/bil/vw/polo/10-tsi-115-highline-dsg-5d/5618299',
#      'gaTrackingText': 'OpenClickXtra'},
#     'tracking': {'rel': 'TrackClick',
#      'href': '/LogMoonrakerClick/5618299/103/1',
#      'method': 'POST'}},
#    {'externalId': 5634005,
#     'priceDisplayValue': '199.900 kr.',
#     'title': 'VW Polo',
#     'subTitle': '1,0 TSi 115 Highline DSG 5d',
#     'infoText': 'Modelår 2018, 53.000 km, Benzin, 21 km/l',
#     'image': {'url': 'https://billeder.bilbasen.dk/bilinfo/4e312274-92b1-44e7-9394-b91558922563.jpeg?class=S960X960'},
#     'link': {'rel': 'Navigate',
#      'href': 'https://www.bilbasen.dk/brugt/bil/vw/polo/10-tsi-115-highline-dsg-5d/5634005',
#      'gaTrackingText': 'OpenClickXtra'},
#     'tracking': {'rel': 'TrackClick',
#      'href': '/LogMoonrakerClick/5634005/103/1',
#      'method': 'POST'}}]},
#  'financing': {'calculationId': '6294b3bf-151b-4282-8f2a-7b695e9eae76',
#   'company': {'id': 22,
#    'name': 'Santander Consumer Bank',
#    'disclaimer': 'Etabl. omk. samt månedligt kontogebyr er medtaget i alle beregninger. Forudsat betaling via Betalingsservice & kaskoforsikring. 14 dages fortrydelsesret.',
#    'provider': 'Sherwood',
#    'brandId': '1',
#    'productId': '1'},
#   'offer': {'id': '3d83eea2-af32-48f7-8d6b-423abda40ae8',
#    'monthlyPrice': '1.877 kr.',
#    'downPaymentPercent': '20%',
#    'downPayment': '29.980 kr.',
#    'loan': '119.920 kr.',
#    'creditCost': '37.682 kr.',
#    'loanWithCreditCost': '157.602 kr.',
#    'loanWithCreditCostAndDownPayment': '187.582 kr.',
#    'annualPercentageRate': '8,43%',
#    'interestRateType': 'Variabel',
#    'debtorInterest': '2,83%',
#    'period': '84 mdr.',
#    'next': {'rel': 'LoanApplication',
#     'href': '/ansoegomlaanetilbud?financeOfferId=3d83eea2-af32-48f7-8d6b-423abda40ae8&globalId=5561550',
#     'method': 'GET',
#     'caption': 'Udfyld låneformular',
#     'gaTrackingText': 'ClickFinanceBannerSherwood'},
#    'raw': {'monthlyPrice': 1877.0,
#     'downPaymentPercent': 20.0,
#     'downPayment': 29980.0,
#     'loan': 119920.0,
#     'creditCost': 37682.0,
#     'loanWithCreditCostAndDownPayment': 187582.0,
#     'annualPercentageRate': 8.43,
#     'debtorInterest': 2.83,
#     'period': 84}},
#   'flowType': 'LoanApplication',
#   'bannerType': 'FinanceWidget',
#   'downPaymentOptions': [{'downPaymentPercent': '20%',
#     'downPayment': '29.980 kr.',
#     'periodOptions': [{'period': '48 mdr.',
#       'periodInMonths': 48,
#       'offerId': 'a2259a13-b26c-4f2a-b48d-25dc00a6aadc'},
#      {'period': '60 mdr.',
#       'periodInMonths': 60,
#       'offerId': '4ada236e-6e10-40c7-bb18-b9ced9ab52cb'},
#      {'period': '72 mdr.',
#       'periodInMonths': 72,
#       'offerId': '05c9f74b-399f-41be-bc82-aeb84a32bb65'},
#      {'period': '84 mdr.',
#       'periodInMonths': 84,
#       'offerId': '3d83eea2-af32-48f7-8d6b-423abda40ae8'}]},
#    {'downPaymentPercent': '30%',
#     'downPayment': '44.970 kr.',
#     'periodOptions': [{'period': '48 mdr.',
#       'periodInMonths': 48,
#       'offerId': '94ad5182-7eba-4b4d-817a-224a9878cd98'},
#      {'period': '60 mdr.',
#       'periodInMonths': 60,
#       'offerId': '7cc60c69-a577-4c29-a4ad-b6c5b4833429'},
#      {'period': '72 mdr.',
#       'periodInMonths': 72,
#       'offerId': '7d34eb40-7982-4d40-9191-053f3e958994'},
#      {'period': '84 mdr.',
#       'periodInMonths': 84,
#       'offerId': '000b5e58-0ded-48d2-8b5c-027b14328bef'}]},
#    {'downPaymentPercent': '40%',
#     'downPayment': '59.960 kr.',
#     'periodOptions': [{'period': '48 mdr.',
#       'periodInMonths': 48,
#       'offerId': '20ef6550-a0d9-471d-a08e-fcd814bc6555'},
#      {'period': '60 mdr.',
#       'periodInMonths': 60,
#       'offerId': 'bc32a468-e5d1-4c7b-bb72-d8dbf1be13ec'},
#      {'period': '72 mdr.',
#       'periodInMonths': 72,
#       'offerId': 'e880897f-0d5a-4382-9f72-62977349591a'},
#      {'period': '84 mdr.',
#       'periodInMonths': 84,
#       'offerId': 'e01f313a-2db3-44db-b49d-8eba1f997d8c'}]}]},
#  'headMeta': {'metaData': {'title': 'Brugt VW Polo 1,0 MPi 75 Trendline 5d - Bilbasen',
#    'description': 'Modelår 2018, Benzin , SKROT-KAMPAGNE\n\nFÅ MIN. 15.000 DKK FOR DIN BYTTEBIL, VED FINANSIERING AF BIL IGENNEM OS.\n\nMed udbetaling:\nBiler under 5 år gamle: 2,25% rente.\n\nUden Udbetaling\n5,59% rente\n\nHos Bilhuset Storm finder du altid et stort udvalg af brugte familiebiler. Vi har altid minimum 70 biler på lager, både benzin og diesel. Vi kan selvfølgelig også hjælpe med forsikring og finansiering af din nye bil både med og uden udbetaling.\n\nVelkommen hos Bilhuset Storm midt på Sjælland.\n\nNY SYNET 02/2022\nLEVERES NY SERVICERET\n\nairc., c.lås, fjernb. c.lås, fartpilot, kørecomputer, infocenter, startspærre, udv. temp. måler, højdejust. førersæde, el-ruder, automatisk start/stop, cd/radio, dæktryksmåler, håndfrit til mobil, bluetooth, musikstreaming via bluetooth, usb tilslutning, isofix, kopholder, stofindtræk, splitbagsæde, læderrat, tågelygter, led kørelys, airbag, abs, antispin, esp, servo, ikke ryger, nysynet, service ok, tidligere undervognsbehandlet\n\nATTRAKTIV FINANSERING KAN SKAFFES MED OG UDEN UDBETALING.\n\nDenne bil er en Euro VI norm hvilket vil sige at den opfylder kravene for at køre i de større byer.\n\nAlle vores biler leveres serviceret og kosmetisk klargjort. Det er din tryghed for en god bilhandel. Ja tak til byttebiler. Finansiering både med og uden udbetaling tilbydes til attraktive renter.\n\nÅBNINGSTIDER hos Bilhuset Storm:\nMandag - fredag: 10:00 - 17:00\nLørdag lukket\nSøndag: 11:00 - 15:00',
#    'keywords': 'VW, Polo, 1,0 MPi 75 Trendline 5d, Benzin, modelår 2018, brugt, billig, til salg, sælges af forhandler',
#    'canonicalUrl': 'https://www.bilbasen.dk/brugt/bil/vw/polo/10-mpi-75-trendline-5d/5561550',
#    'adImageUrl': 'https://billeder.bilbasen.dk/bilinfo/87814a8a-1928-485d-8df2-3538b48b7840.jpeg?class=S960X960'},
#   'facebookPixelData': {'iframeSourceUrl': '#'},
#   'optimizelyWebCdn': {'enableOptimizelyWebCdn': False,
#    'optimizelySourceUrl': '#'},
#   'platformDetector': {'isDisplayedInAppWebview': False}},
#  'breadCrumbs': [{'url': '/brugt/bil/vw', 'text': 'VW', 'ariaLabel': 'mærke'},
#   {'url': '/brugt/bil/vw/polo', 'text': 'Polo', 'ariaLabel': 'model'},
#   {'url': '/brugt/bil/vw/polo/1,0_mpi_75_trendline_5d',
#    'text': '1,0 MPi 75 Trendline 5d',
#    'ariaLabel': 'variant'}],
#  'popularSearches': [{'url': 'https://www.bilbasen.dk/brugt/bil/vw/polo/ps-gti',
#    'linkText': 'gti'},
#   {'url': 'https://www.bilbasen.dk/brugt/bil/vw/polo/ps-vw_polo',
#    'linkText': 'vw polo'},
#   {'url': 'https://www.bilbasen.dk/brugt/bil/vw/polo/ps-polo',
#    'linkText': 'polo'},
#   {'url': 'https://www.bilbasen.dk/brugt/bil/vw/polo/ps-gt', 'linkText': 'gt'},
#   {'url': 'https://www.bilbasen.dk/brugt/bil/vw/polo/ps-polo_tdi',
#    'linkText': 'polo tdi'},
#   {'url': 'https://www.bilbasen.dk/brugt/bil/vw/polo/ps-vw', 'linkText': 'vw'},
#   {'url': 'https://www.bilbasen.dk/brugt/bil/vw/polo/ps-vw_polo_serie',
#    'linkText': 'vw polo serie'},
#   {'url': 'https://www.bilbasen.dk/brugt/bil/vw/polo/ps-polo_gti',
#    'linkText': 'polo gti'},
#   {'url': 'https://www.bilbasen.dk/brugt/bil/vw/polo/ps-r_line',
#    'linkText': 'r line'},
#   {'url': 'https://www.bilbasen.dk/brugt/bil/vw/polo/ps-automatgear',
#    'linkText': 'automatgear'},
#   {'url': 'https://www.bilbasen.dk/brugt/bil/vw/polo/ps-highline',
#    'linkText': 'highline'},
#   {'url': 'https://www.bilbasen.dk/brugt/bil/vw/polo/ps-vw_polo_2,0_gti_dsg_5d',
#    'linkText': 'vw polo 2,0 gti dsg 5d'},
#   {'url': 'https://www.bilbasen.dk/brugt/bil/vw/polo/ps-bluegt',
#    'linkText': 'bluegt'},
#   {'url': 'https://www.bilbasen.dk/brugt/bil/vw/polo/ps-dsg',
#    'linkText': 'dsg'},
#   {'url': 'https://www.bilbasen.dk/brugt/bil/vw/polo/ps-polo_gt',
#    'linkText': 'polo gt'},
#   {'url': 'https://www.bilbasen.dk/brugt/bil/vw/polo/ps-vw_polo_2012',
#    'linkText': 'vw polo 2012'},
#   {'url': 'https://www.bilbasen.dk/brugt/bil/vw/polo/ps-vw_polo_2013',
#    'linkText': 'vw polo 2013'},
#   {'url': 'https://www.bilbasen.dk/brugt/bil/vw/polo/ps-12312',
#    'linkText': '1.2'},
#   {'url': 'https://www.bilbasen.dk/brugt/bil/vw/polo/ps-tsi',
#    'linkText': 'tsi'},
#   {'url': 'https://www.bilbasen.dk/brugt/bil/vw/polo/ps-polo_2022_r_line',
#    'linkText': 'polo 2022 r line'}],
#  'environment': {'name': 'bb_env', 'value': 'prod'}}
